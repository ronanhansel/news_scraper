# %%
import pandas as pd

# %% [markdown]
# # Data Manipulation

# %%
df_Yh = pd.read_csv('Yahoo_output_all.csv')
df_Yh['source'] = 'Yahoo'
df_CNBC = pd.read_csv('CNBC_output_all.csv')
df_CNBC['source'] = 'CNBC'
df = pd.concat([df_Yh, df_CNBC], ignore_index=True)
df
# Out:
#                            Author  \
# 0                  Brooke DiPalma
# 1                       Ronda Lee
# 2                 Alexandra Canal
# 3                Pras Subramanian
# 4    Karen Friar and Josh Schafer
# ..                            ...
# 357        Annika Kim Constantino
# 358                  Stefan Sykes
# 359               Michael Wayland
# 360                  Stefan Sykes
# 361                 Melissa Repko
#
#                                                  Title  \
# 0    How Lululemon parlayed yoga pants into an entr...
# 1    Student loan repayments will have a 'limited' ...
# 2    Netflix subscribers surge as company announces...
# 3    Tesla earnings: Q3 revenue and profit miss est...
# 4    Stocks plummet, yields rise after earnings war...
# ..                                                 ...
# 357  Covid shot rollout off to a bumpy start as som...
# 358  Anheuser-Busch to stop cutting off Clydesdale ...
# 359  GM executive slams UAW over ‘flow of misinform...
# 360  Philip Morris weighs options for pharmaceutica...
# 361  Walmart opens pet center with veterinary care ...
#
#                                                Content source
# 0    Lululemon is finally aligning with Wall Street...  Yahoo
# 1    Researchers at the Federal Reserve Bank of New...  Yahoo
# 2    Netflix (NFLX) reported a surge in third quart...  Yahoo
# 3    Tesla (TSLA) stock was volatile in after-hours...  Yahoo
# 4    Stocks sold off on Wednesday, as a tightening ...  Yahoo
# ..                                                 ...    ...
# 357  In this article\nThe rollout of a new round of...   CNBC
# 358  In this article\nAnheuser-Busch\nInBev said it...   CNBC
# 359  In this article\nDETROIT – As the United Auto ...   CNBC
# 360  In this article\nPhilip Morris International\n...   CNBC
# 361  In this article\nWalmart\nis opening a dedicat...   CNBC
#
# [362 rows x 4 columns]

# %%
df[:3]
# Out:
#             Author                                              Title  \
# 0   Brooke DiPalma  How Lululemon parlayed yoga pants into an entr...
# 1        Ronda Lee  Student loan repayments will have a 'limited' ...
# 2  Alexandra Canal  Netflix subscribers surge as company announces...
#
#                                              Content source
# 0  Lululemon is finally aligning with Wall Street...  Yahoo
# 1  Researchers at the Federal Reserve Bank of New...  Yahoo
# 2  Netflix (NFLX) reported a surge in third quart...  Yahoo

# %%
# Sentiment analysis using VADER
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Create a sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Analyze the sentiment of the news article text
df['neg'] = df['Title'].apply(lambda x: analyzer.polarity_scores(x)['neg'])
df['neu'] = df['Title'].apply(lambda x: analyzer.polarity_scores(x)['neu'])
df['pos'] = df['Title'].apply(lambda x: analyzer.polarity_scores(x)['pos'])
df['com'] = df['Title'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
# The sentiment_scores dictionary will contain sentiment scores (neg, neu, pos, com)
df
# Out:
#                            Author  \
# 0                  Brooke DiPalma
# 1                       Ronda Lee
# 2                 Alexandra Canal
# 3                Pras Subramanian
# 4    Karen Friar and Josh Schafer
# ..                            ...
# 357        Annika Kim Constantino
# 358                  Stefan Sykes
# 359               Michael Wayland
# 360                  Stefan Sykes
# 361                 Melissa Repko
#
#                                                  Title  \
# 0    How Lululemon parlayed yoga pants into an entr...
# 1    Student loan repayments will have a 'limited' ...
# 2    Netflix subscribers surge as company announces...
# 3    Tesla earnings: Q3 revenue and profit miss est...
# 4    Stocks plummet, yields rise after earnings war...
# ..                                                 ...
# 357  Covid shot rollout off to a bumpy start as som...
# 358  Anheuser-Busch to stop cutting off Clydesdale ...
# 359  GM executive slams UAW over ‘flow of misinform...
# 360  Philip Morris weighs options for pharmaceutica...
# 361  Walmart opens pet center with veterinary care ...
#
#                                                Content source  \
# 0    Lululemon is finally aligning with Wall Street...  Yahoo
# 1    Researchers at the Federal Reserve Bank of New...  Yahoo
# 2    Netflix (NFLX) reported a surge in third quart...  Yahoo
# 3    Tesla (TSLA) stock was volatile in after-hours...  Yahoo
# 4    Stocks sold off on Wednesday, as a tightening ...  Yahoo
# ..                                                 ...    ...
# 357  In this article\nThe rollout of a new round of...   CNBC
# 358  In this article\nAnheuser-Busch\nInBev said it...   CNBC
# 359  In this article\nDETROIT – As the United Auto ...   CNBC
# 360  In this article\nPhilip Morris International\n...   CNBC
# 361  In this article\nWalmart\nis opening a dedicat...   CNBC
#
#                                       sentiment_scores    neg    neu    pos  \
# 0    {'neg': 0.116, 'neu': 0.764, 'pos': 0.12, 'com...  0.116  0.764  0.120
# 1    {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'comp...  0.137  0.863  0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 3    {'neg': 0.097, 'neu': 0.727, 'pos': 0.176, 'co...  0.097  0.727  0.176
# 4    {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...  0.180  0.820  0.000
# ..                                                 ...    ...    ...    ...
# 357  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 358  {'neg': 0.316, 'neu': 0.684, 'pos': 0.0, 'comp...  0.316  0.684  0.000
# 359  {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compou...  0.130  0.870  0.000
# 360  {'neg': 0.0, 'neu': 0.604, 'pos': 0.396, 'comp...  0.000  0.604  0.396
# 361  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...  0.000  0.775  0.225
#
#         com
# 0    0.0258
# 1   -0.2263
# 2    0.0000
# 3    0.3182
# 4   -0.2960
# ..      ...
# 357  0.0000
# 358 -0.4019
# 359 -0.1280
# 360  0.7096
# 361  0.4939
#
# [362 rows x 9 columns]
